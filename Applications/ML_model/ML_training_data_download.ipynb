# %%
"""
Purpose:
--------
Demonstrate how to create a dataframe with all of the red_blue
split points from the datajoint database

Applications
------------
1. Query this dataframe for a high fidelity subset
2. Plot single/multiple red-blue splits or for the entire segment
"""

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import connects_neuvue

# %% [markdown]
# # Step 1: Import API and configure API object with aws secret

# %%
from connects_neuvue.utils import aws_utils as aws
secret_dict = aws.get_secret()

# %%
from connects_neuvue.h01_c2 import api
fetcher = api.API(secret_dict=secret_dict)
fetcher

# %% [markdown]
# # Step 2: Downloading Networkx Objects and Training Data

# %% [markdown]
# ### downloading just one networkx object and ground truth labels

# %%
segment_id = 1087542412

# %%
"""
Purpose
-------
Download all of the networkx graphs and training data used for the 
training of the machine learning classifiers

Pseudocode
----------
1. Donwload all the networkx files
2. Download
"""

# %%
keys = [dict(segment_id = 344045868),dict(segment_id=357812369)]
keys

# %%
import pandas as pd
from tqdm import tqdm
from connects_neuvue.utils import file_utils as fu

ml_train_data = fetcher.ml_training_data(
    #keys
)

# %%
from datasci_tools import system_utils as su

# %%
ml_train_data["training_labels"][2]
# Out:
# {'AxonOnDendriteErrorDetector': ['L0_19',
#   'L0_25',
#   'L0_32',
#   'L0_33',
#   'L0_35',
#   'L0_36',
#   'L1_1',
#   'L1_14',
#   'L1_15',
#   'L1_16'],
#  'ExcAxonHighDegreeErrorDetector': ['L5_31',
#   'L5_32',
#   'L5_33',
#   'L5_73',
#   'L5_80'],
#  'ExcAxonLowDegreeErrorDetector': ['L5_31',
#   'L5_32',
#   'L5_33',
#   'L5_73',
#   'L5_79',
#   'L5_80'],
#  'DendriteCrossRoadsErrorDetector': ['L0_9',
#   'L0_12',
#   'L0_25',
#   'L0_32',
#   'L0_35',
#   'L0_36',
#   'L2_9',
#   'L2_11'],
#  'DendriteDoubleBackErrorDetector': ['L0_25', 'L0_35', 'L1_16'],
#  'DendriteWidthJumpErrorDetector': [],
#  'DendriteInternalBendErrorDetector': ['L0_36', 'L2_15'],
#  'ExcAxonWidthJumpErrorDetector': [],
#  'segment_id': 5092026676,
#  'cell_type': 'excitatory'}

# %%
ml_train_data["training_labels"] = [k["limb_branch_dict_to_cancel"] for k in ml_train_data["limb_branch_to_cancel"]]
ml_train_data
# Out:
#        segment_id  split_index  \
# 0     64440258236            0
# 1      5087163890            0
# 2      5092026676            0
# 3     13995672868            0
# 4      4915850339            0
# ...           ...          ...
# 8236  42270129636            0
# 8237  38441996393            0
# 8238  66077820722            0
# 8239  22660694549            0
# 8240   5671379404            0
#
#                              neuron_graph_high_fid_axon  \
# 0     /home/neurd/githubRepos/connects_neuvue/Applic...
# 1     /home/neurd/githubRepos/connects_neuvue/Applic...
# 2     /home/neurd/githubRepos/connects_neuvue/Applic...
# 3     /home/neurd/githubRepos/connects_neuvue/Applic...
# 4     /home/neurd/githubRepos/connects_neuvue/Applic...
# ...                                                 ...
# 8236  /home/neurd/githubRepos/connects_neuvue/Applic...
# 8237  /home/neurd/githubRepos/connects_neuvue/Applic...
# 8238  /home/neurd/githubRepos/connects_neuvue/Applic...
# 8239  /home/neurd/githubRepos/connects_neuvue/Applic...
# 8240  /home/neurd/githubRepos/connects_neuvue/Applic...
#
#                                   limb_branch_to_cancel  \
# 0     {'axon_on_dendrite_merges_limb_branch_dict_to_...
# 1     {'axon_on_dendrite_merges_limb_branch_dict_to_...
# 2     {'axon_on_dendrite_merges_limb_branch_dict_to_...
# 3     {'axon_on_dendrite_merges_limb_branch_dict_to_...
# 4     {'axon_on_dendrite_merges_limb_branch_dict_to_...
# ...                                                 ...
# 8236  {'axon_on_dendrite_merges_limb_branch_dict_to_...
# 8237  {'axon_on_dendrite_merges_limb_branch_dict_to_...
# 8238  {'axon_on_dendrite_merges_limb_branch_dict_to_...
# 8239  {'axon_on_dendrite_merges_limb_branch_dict_to_...
# 8240  {'axon_on_dendrite_merges_limb_branch_dict_to_...
#
#                                                       G  \
# 0     (S0, L0_2, L0_0, L0_1, L1_0, L2_2, L2_0, L2_1,...
# 1     (S0, L0_0, L0_1, L0_2, L0_3, L0_4, L0_5, L0_6,...
# 2     (S0, L0_2, L0_1, L0_3, L0_0, L0_4, L0_5, L0_6,...
# 3     (S0, L0_1, L0_2, L0_3, L0_4, L0_5, L0_6, L0_0,...
# 4     (S0, L0_0, L0_1, L0_2, L0_3, L0_4, L0_5, L0_6,...
# ...                                                 ...
# 8236  (S0, L0_1, L0_0, L0_2, L0_3, L0_4, L0_5, L0_6,...
# 8237  (S0, L0_3, L0_0, L0_4, L0_1, L0_2, L0_5, L0_6,...
# 8238  (S0, L0_28, L0_29, L0_30, L0_16, L0_31, L0_14,...
# 8239  (S0, L0_4, L0_8, L0_9, L0_5, L0_7, L0_11, L0_1...
# 8240  (S0, L0_0, L0_1, L0_2, L0_3, L0_4, L0_5, L0_6,...
#
#                                         training_labels
# 0     {'AxonOnDendriteErrorDetector': ['L2_0', 'L2_1...
# 1     {'AxonOnDendriteErrorDetector': ['L0_2', 'L0_1...
# 2     {'AxonOnDendriteErrorDetector': ['L0_19', 'L0_...
# 3     {'AxonOnDendriteErrorDetector': [], 'InhAxonHi...
# 4     {'AxonOnDendriteErrorDetector': ['L0_3', 'L0_5...
# ...                                                 ...
# 8236  {'AxonOnDendriteErrorDetector': ['L1_33', 'L1_...
# 8237  {'AxonOnDendriteErrorDetector': [], 'InhAxonHi...
# 8238  {'AxonOnDendriteErrorDetector': [], 'InhAxonHi...
# 8239  {'AxonOnDendriteErrorDetector': ['L5_0'], 'Inh...
# 8240  {'AxonOnDendriteErrorDetector': ['L0_2', 'L0_2...
#
# [8241 rows x 6 columns]

# %%
ml_train_data_to_save = ml_train_data[["segment_id","split_index","G","training_labels"]].copy()
ml_train_data_to_save['cell_type'] = [k["cell_type"] for k in ml_train_data_to_save["training_labels"]]

keys_to_delete = ["segment_id","cell_type"]
ml_train_data_to_save['training_labels'] = ml_train_data_to_save['training_labels'].apply(
    lambda d: {k: v for k, v in d.items() if k not in keys_to_delete}
)
ml_train_data_to_save
# Out:
#        segment_id  split_index  \
# 0     64440258236            0
# 1      5087163890            0
# 2      5092026676            0
# 3     13995672868            0
# 4      4915850339            0
# ...           ...          ...
# 8236  42270129636            0
# 8237  38441996393            0
# 8238  66077820722            0
# 8239  22660694549            0
# 8240   5671379404            0
#
#                                                       G  \
# 0     (S0, L0_2, L0_0, L0_1, L1_0, L2_2, L2_0, L2_1,...
# 1     (S0, L0_0, L0_1, L0_2, L0_3, L0_4, L0_5, L0_6,...
# 2     (S0, L0_2, L0_1, L0_3, L0_0, L0_4, L0_5, L0_6,...
# 3     (S0, L0_1, L0_2, L0_3, L0_4, L0_5, L0_6, L0_0,...
# 4     (S0, L0_0, L0_1, L0_2, L0_3, L0_4, L0_5, L0_6,...
# ...                                                 ...
# 8236  (S0, L0_1, L0_0, L0_2, L0_3, L0_4, L0_5, L0_6,...
# 8237  (S0, L0_3, L0_0, L0_4, L0_1, L0_2, L0_5, L0_6,...
# 8238  (S0, L0_28, L0_29, L0_30, L0_16, L0_31, L0_14,...
# 8239  (S0, L0_4, L0_8, L0_9, L0_5, L0_7, L0_11, L0_1...
# 8240  (S0, L0_0, L0_1, L0_2, L0_3, L0_4, L0_5, L0_6,...
#
#                                         training_labels   cell_type
# 0     {'AxonOnDendriteErrorDetector': ['L2_0', 'L2_1...  inhibitory
# 1     {'AxonOnDendriteErrorDetector': ['L0_2', 'L0_1...  excitatory
# 2     {'AxonOnDendriteErrorDetector': ['L0_19', 'L0_...  excitatory
# 3     {'AxonOnDendriteErrorDetector': [], 'InhAxonHi...  inhibitory
# 4     {'AxonOnDendriteErrorDetector': ['L0_3', 'L0_5...  excitatory
# ...                                                 ...         ...
# 8236  {'AxonOnDendriteErrorDetector': ['L1_33', 'L1_...  inhibitory
# 8237  {'AxonOnDendriteErrorDetector': [], 'InhAxonHi...  inhibitory
# 8238  {'AxonOnDendriteErrorDetector': [], 'InhAxonHi...  inhibitory
# 8239  {'AxonOnDendriteErrorDetector': ['L5_0'], 'Inh...  inhibitory
# 8240  {'AxonOnDendriteErrorDetector': ['L0_2', 'L0_2...  excitatory
#
# [8241 rows x 5 columns]

# %%
su.save_object(ml_train_data_to_save,"ml_training_data_8k.pkl")
# Out:
# Saved object at /home/neurd/githubRepos/connects_neuvue/Applications/ML_model/ml_training_data_8k.pkl
# File size is 4856.74617 MB
# 64440258236

# %%
reload_data = su.load_object("./ml_training_data_8k.pkl")

# %% [markdown]
# # Checking that the node names in training labels are all aligned with nodes in the graph object

# %%
from tqdm import tqdm

data = ml_train_data_to_save

for idx in tqdm(range(len(ml_train_data_to_save))):
    train_dict = data.iloc[idx].to_dict()
    G = train_dict["G"]
    limb_branch = train_dict["training_labels"]
    
    for error_type,branches in limb_branch.items():
        for b in branches:
            if b not in G:
                raise Exception("")
# Out:
# 100%|██████████| 8241/8241 [00:00<00:00, 10772.52it/s]

# %%
G.nodes["L0_9"]
# Out:
# {'area': 36.034437754266754,
#  'compartment': None,
#  'axon_compartment': 'dendrite',
#  'boutons_cdfs': None,
#  'boutons_volume': None,
#  'labels': ['axon-error', 'axon-like'],
#  'mesh_center': array([2495040.19470199, 1192346.82582781,  106825.46205298]),
#  'endpoint_upstream': array([2493790., 1158090.,  104918.]),
#  'endpoint_downstream': array([2503267.47602172, 1222793.10862306,  108564.45905347]),
#  'mesh_volume': 1.2523518924333088,
#  'n_boutons': 0,
#  'n_spines': 0,
#  'n_synapses': 1,
#  'n_synapses_head': 0,
#  'n_synapses_neck': 0,
#  'n_synapses_no_head': 0,
#  'n_synapses_post': 0,
#  'n_synapses_pre': 1,
#  'n_synapses_shaft': 1,
#  'n_synapses_spine': 0,
#  'skeletal_length': 73450.04034986418,
#  'spine_density': 0.0,
#  'spine_volume_density': 0,
#  'spine_volume_median': 0,
#  'synapse_density': 1.3614696400937363e-05,
#  'synapse_density_post': 0.0,
#  'synapse_density_pre': 1.3614696400937363e-05,
#  'total_spine_volume': 0,
#  'width': 267.51616926676013,
#  'width_new': 80.85454991996053,
#  'soma_distance_euclidean': 52252.770929232036,
#  'soma_distance_skeletal': 56121.5159633998,
#  'skeleton_vector_upstream': array([-0.22479881,  0.8879296 , -0.40130601]),
#  'skeleton_vector_downstream': array([ 0.58657167,  0.79832747, -0.1364072 ]),
#  'width_upstream': 80.85454991996053,
#  'width_downstream': 99.10829666387411,
#  'min_dist_synapses_pre_upstream': 55695.32278901908,
#  'min_dist_synapses_post_upstream': inf,
#  'min_dist_synapses_pre_downstream': 17754.71756084456,
#  'min_dist_synapses_post_downstream': inf,
#  'spine_data': [],
#  'synapse_data': [{'upstream_dist': 55695.32278901908,
#    'head_neck_shaft': 'shaft',
#    'syn_id': 3129320211893952,
#    'volume': 21098880,
#    'syn_type': 'presyn'}],
#  'width_data': [{'upstream_dist': 1000.0000000000205,
#    'width': 80.85454991996053},
#   {'upstream_dist': 1993.3574635977084, 'width': 80.85454991996053},
#   {'upstream_dist': 2986.403335235882, 'width': 80.85454991996053},
#   {'upstream_dist': 3980.7820593792576, 'width': 101.39056417761847},
#   {'upstream_dist': 4966.85571701477, 'width': 93.21957883234948},
#   {'upstream_dist': 5965.9074985016, 'width': 106.04112809576955},
#   {'upstream_dist': 6963.757717484425, 'width': 91.11193264225226},
#   {'upstream_dist': 7954.791949417907, 'width': 90.23613743387457},
#   {'upstream_dist': 8948.408580617786, 'width': 128.43898556153405},
#   {'upstream_dist': 9945.690623640197, 'width': 39.36465552838164},
#   {'upstream_dist': 10937.429043465696, 'width': 83.8937291547113},
#   {'upstream_dist': 11936.543717999262, 'width': 63.25188022234099},
#   {'upstream_dist': 12934.542013129276, 'width': 59.94779987188432},
#   {'upstream_dist': 13932.437284572357, 'width': 39.546642362958764},
#   {'upstream_dist': 14931.200057892222, 'width': 68.68460756219628},
#   {'upstream_dist': 15927.531854631012, 'width': 49.70138998315467},
#   {'upstream_dist': 16927.110264626383, 'width': 56.55042434620184},
#   {'upstream_dist': 17926.21358099344, 'width': 57.37081851329732},
#   {'upstream_dist': 18925.877066792567, 'width': 52.225395706107},
#   {'upstream_dist': 19925.614689993996, 'width': 76.01553596801423},
#   {'upstream_dist': 20924.594435560564, 'width': 90.58488042755093},
#   {'upstream_dist': 21920.31112458376, 'width': 53.87694000538126},
#   {'upstream_dist': 22918.368144925324, 'width': 43.147815905799035},
#   {'upstream_dist': 23914.103540888205, 'width': 65.78377685330652},
#   {'upstream_dist': 24913.444522144655, 'width': 69.55767635537707},
#   {'upstream_dist': 25909.48426782928, 'width': 33.98427759754766},
#   {'upstream_dist': 26908.135436649467, 'width': 102.07101331553571},
#   {'upstream_dist': 27906.088281383625, 'width': 71.50086806244606},
#   {'upstream_dist': 28905.708565407505, 'width': 45.2773951521422},
#   {'upstream_dist': 29904.5992541626, 'width': 63.301684912014},
#   {'upstream_dist': 30903.779280093553, 'width': 89.10473617015849},
#   {'upstream_dist': 31902.52218863405, 'width': 113.19936618808372},
#   {'upstream_dist': 32901.9213072715, 'width': 77.73067777065657},
#   {'upstream_dist': 33900.42815214952, 'width': 47.136118539390125},
#   {'upstream_dist': 34898.111810093236, 'width': 66.13608932150575},
#   {'upstream_dist': 35893.798656563034, 'width': 69.03890027231617},
#   {'upstream_dist': 36890.10209921978, 'width': 94.712375773989},
#   {'upstream_dist': 37889.10918458865, 'width': 88.18856096713505},
#   {'upstream_dist': 38877.85768717542, 'width': 127.42083534628395},
#   {'upstream_dist': 39862.49101945504, 'width': 80.92620701180363},
#   {'upstream_dist': 40862.22814297488, 'width': 122.3658357809564},
#   {'upstream_dist': 41862.106490445476, 'width': 140.50868415201109},
#   {'upstream_dist': 42859.715641101946, 'width': 72.96225149689981},
#   {'upstream_dist': 43845.2075863558, 'width': 86.00795593064348},
#   {'upstream_dist': 44838.214587527305, 'width': 146.66917572873606},
#   {'upstream_dist': 45826.06167216007, 'width': 76.09078769515484},
#   {'upstream_dist': 46823.62295672005, 'width': 84.01931150101152},
#   {'upstream_dist': 47821.9183969213, 'width': 40.919522187575666},
#   {'upstream_dist': 48819.7263325905, 'width': 68.7548866451592},
#   {'upstream_dist': 49816.15710945656, 'width': 97.94632750006186},
#   {'upstream_dist': 50812.72387453883, 'width': 157.88559362745687},
#   {'upstream_dist': 51812.29342350863, 'width': 160.23333118144956},
#   {'upstream_dist': 52810.20903621332, 'width': 80.85454991996053},
#   {'upstream_dist': 53807.61110033138, 'width': 70.58344477588247},
#   {'upstream_dist': 54807.3035967097, 'width': 71.37082769460157},
#   {'upstream_dist': 55807.2277395172, 'width': 355.8434201239282},
#   {'upstream_dist': 56807.025453537695, 'width': 331.2759951717945},
#   {'upstream_dist': 57806.56421410333, 'width': 39.59483070961366},
#   {'upstream_dist': 58806.18208327421, 'width': 88.54705236490172},
#   {'upstream_dist': 59804.60788580067, 'width': 57.31730536635624},
#   {'upstream_dist': 60797.55328394841, 'width': 74.5721689141301},
#   {'upstream_dist': 61795.08467085284, 'width': 123.43491674654821},
#   {'upstream_dist': 62794.61833738428, 'width': 105.63662007076381},
#   {'upstream_dist': 63794.34905192747, 'width': 116.026546300548},
#   {'upstream_dist': 64793.42938757139, 'width': 67.39617753684281},
#   {'upstream_dist': 65792.27552698686, 'width': 96.10483015127922},
#   {'upstream_dist': 66787.22765066977, 'width': 90.3521752851525},
#   {'upstream_dist': 67783.29877756345, 'width': 67.40543837159471},
#   {'upstream_dist': 68782.38680901189, 'width': 76.56295023073974},
#   {'upstream_dist': 69781.49897894368, 'width': 80.32570969557162},
#   {'upstream_dist': 70780.14051941376, 'width': 87.12215817691245},
#   {'upstream_dist': 71779.78165908216, 'width': 110.84047760170162},
#   {'upstream_dist': 72779.60159157212, 'width': 86.62746987205443},
#   {'upstream_dist': 73229.54387871858, 'width': 99.85694251786629}],
#  'skeleton_data': array([[2493790.        , 1158090.        ,  104918.        ],
#         [2493831.74878316, 1158910.51578228,  104347.90273625],
#         [2493816.12794139, 1159744.69338073,  103808.7712365 ],
#         [2493428.71800844, 1160618.99939456,  103541.1098063 ],
#         [2492851.25612126, 1161419.1742047 ,  103418.44322933],
#         [2492413.87293593, 1162282.96345929,  103231.61354453],
#         [2492377.39148367, 1163255.40349146,  103005.48537385],
#         [2492235.87375719, 1164196.63227884,  102705.87535663],
#         [2491825.89005416, 1165060.37129242,  102445.07442002],
#         [2491095.88303311, 1165734.17410727,  102463.87669937],
#         [2490460.49294579, 1166472.6252105 ,  102677.27978843],
#         [2489917.37101742, 1167302.34929581,  102666.25225288],
#         [2489457.83523757, 1168135.84821059,  102362.38294058],
#         [2489106.99607833, 1169039.63584817,  102125.56996038],
#         [2488905.48854821, 1170015.2084805 ,  102066.85261095],
#         [2488793.11701641, 1171006.31260983,  102117.96348089],
#         [2488833.53235616, 1171978.15853219,  102333.73918086],
#         [2489060.1727376 , 1172938.11131239,  102495.85579021],
#         [2489185.08808709, 1173914.82176934,  102665.09017062],
#         [2489309.41401434, 1174892.10524994,  102834.75792593],
#         [2489509.31793085, 1175860.45917191,  102982.4211279 ],
#         [2489821.40675602, 1176800.15473382,  103114.83467776],
#         [2490285.30083316, 1177640.42046519,  103379.80167699],
#         [2490705.99540984, 1178416.08747458,  103846.14337526],
#         [2491080.4576829 , 1179100.90741635,  104464.43831474],
#         [2491590.38090467, 1179627.2222471 ,  105143.88912507],
#         [2492013.45934134, 1180249.4546286 ,  105796.51970573],
#         [2492344.74427586, 1181000.26295529,  106365.59026878],
#         [2492869.34267445, 1181719.49446007,  106816.60295489],
#         [2493463.5236973 , 1182447.35906737,  107157.78140932],
#         [2494007.56875421, 1183237.31957378,  107436.63617877],
#         [2494450.68707754, 1184118.78520123,  107594.82980492],
#         [2494782.15698152, 1185049.29823671,  107742.34451923],
#         [2494956.57350273, 1186007.12914045,  107968.03775195],
#         [2495188.70610749, 1186941.92583959,  108231.25914991],
#         [2495442.33773218, 1187802.6262118 ,  108667.42259356],
#         [2495625.10017605, 1188698.39706931,  109061.86492923],
#         [2495996.35696842, 1189620.78185917,  109125.07286703],
#         [2496401.08251099, 1190529.44903207,  109032.68043925],
#         [2496482.58115564, 1191462.92013906,  108717.06474779],
#         [2496598.12574093, 1192429.97496419,  108572.29868464],
#         [2496962.6037197 , 1193357.03564373,  108657.08438857],
#         [2497303.44014616, 1194293.74401236,  108735.59981558],
#         [2497625.06497122, 1195238.04658212,  108726.98900187],
#         [2497686.09139094, 1196182.05135045,  108450.71893902],
#         [2497237.62489075, 1196904.80332757,  107938.30281695],
#         [2496788.51085031, 1197746.13945869,  107680.83057424],
#         [2496557.30845243, 1198716.45099678,  107693.84928078],
#         [2496309.6308219 , 1199682.16091069,  107745.36568049],
#         [2495963.93543891, 1200617.44505174,  107782.22967603],
#         [2495814.46043982, 1201575.21349871,  108012.90503169],
#         [2495933.20931621, 1202526.53768032,  108284.9828204 ],
#         [2496151.37951036, 1203407.61594892,  108703.60213938],
#         [2496309.68387464, 1204331.52623541,  109045.89599098],
#         [2496446.55194573, 1205316.51400993,  109122.55818941],
#         [2496524.32428662, 1206313.17443942,  109120.42779095],
#         [2496538.66801199, 1207312.99569524,  109120.50075983],
#         [2496608.66688608, 1208310.30978396,  109112.73963792],
#         [2496659.12461616, 1209305.50843169,  109034.5641756 ],
#         [2496647.82905883, 1210292.10505632,  108874.14162412],
#         [2496752.5531495 , 1211267.26462688,  108687.19040075],
#         [2497141.73415329, 1212170.40066722,  108549.98980806],
#         [2497662.84638758, 1213017.5369237 ,  108473.36689971],
#         [2498022.36570674, 1213949.82703472,  108498.83371288],
#         [2498485.42484882, 1214833.6557466 ,  108561.15979569],
#         [2498904.18090144, 1215739.4716109 ,  108609.14422491],
#         [2499286.53374031, 1216661.11154746,  108563.54001267],
#         [2499746.95416782, 1217501.52844456,  108831.20061384],
#         [2500197.29717723, 1218353.17802253,  109084.26554632],
#         [2500700.51280054, 1219216.21925611,  109073.74128013],
#         [2501291.20486628, 1220021.94643003,  109063.17090704],
#         [2501914.68998233, 1220797.93352241,  108983.20048198],
#         [2502485.86914274, 1221590.22014338,  108770.31862494],
#         [2503036.47784802, 1222414.80631161,  108641.75890248],
#         [2503267.47602172, 1222793.10862306,  108564.45905347]]),
#  'parent_skeletal_angle': 64.13,
#  'siblings_skeletal_angle_max': 67.26,
#  'siblings_skeletal_angle_min': 67.26,
#  'children_skeletal_angle_max': -1.0,
#  'children_skeletal_angle_min': -1.0,
#  'is_axon_in_downstream_branches': False,
#  'ray_trace_perc': 205.98488818748143,
#  'synapse_closer_to_downstream_endpoint_than_upstream': True,
#  'n_synapses_post_spine': 0,
#  'downstream_dist_min_over_syn': 17754.71756084456,
#  'downstream_upstream_diff_of_most_downstream_syn': -37940.60522817452,
#  'total_upstream_skeletal_length': 56121.5159633998,
#  'closest_mesh_skeleton_dist': 4.8195784663980135,
#  'n_faces_branch': 3008,
#  'n_downstream_nodes': 0,
#  'distance_from_soma': 56121.5159633998,
#  'synapse_pre_perc': 1.0,
#  'axon_width': 80.85454991996053,
#  'synapse_pre_perc_downstream': 1.0,
#  'n_synapses_post_downstream': 0,
#  'skeletal_length_downstream': 73450.04034986418,
#  'n_synapses_downstream': 1,
#  'parent_width': 578.2331728532876,
#  'is_axon': False,
#  'width_downstream_extra_offset': 93.22850271821585,
#  'width_upstream_extra_offset': 86.0132595079301,
#  'max_skeleton_endpoint_dist': 3151.5753029239913,
#  'skeleton_smooth_vector_downstream_extra_offset': array([0.45662498, 0.88742317, 0.06303768]),
#  'skeleton_smooth_vector_upstream_extra_offset': array([-0.44592211,  0.88499973, -0.13389905]),
#  'skeleton_smooth_vector_downstream': array([ 0.5601651 ,  0.82404388, -0.08465662]),
#  'skeleton_smooth_vector_upstream': array([-0.23515596,  0.89757275, -0.37291399]),
#  'width_min': 80.85454991996053,
#  'width_max': 99.10829666387411,
#  'internal_bend_angle_max': 45.242958219911976,
#  'internal_bend_index_perc': 0.22418478260869565,
#  'downstream_endnode_skeletal_distance_from_soma': 129571.55631326398,
#  'sibling_angle_smooth_max': 61.52,
#  'sibling_angle_smooth_min': 61.52,
#  'sibling_angle_smooth_extra_offset_max': 43.47,
#  'sibling_angle_smooth_extra_offset_min': 43.47,
#  'n_children_with_skip_distance': 0,
#  'n_children': 0,
#  'parent_skeletal_angle_smooth': 65.99,
#  'parent_skeletal_angle_smooth_extra_offset': 54.95}

# %%
nodes = [

# %%
from tqdm import tqdm
from connects_neuvue.utils import file_utils as fu
Gs = []
for G_path in tqdm(training_df["neuron_graph_high_fid_axon"].to_list()):
    Gs.append(fu.decompress_pickle(G_path))
training_df[G] = Gs
training_df

# %%
G = fetcher.G_axon_from_segment_id(segment_id)

# %%
fetcher.autoproof_table()

# %%
labels = fetcher.ml_G_training_labels(segment_id)
labels
