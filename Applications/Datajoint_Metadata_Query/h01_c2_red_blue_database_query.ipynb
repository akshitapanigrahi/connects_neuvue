# %%
"""
Purpose:
--------
Demonstrate how to create a dataframe with all of the red_blue
split points from the datajoint database

Applications
------------
1. Query this dataframe for a high fidelity subset
2. Plot single/multiple red-blue splits or for the entire segment
"""
# Out:
# '\nPurpose:\n--------\nDemonstrate how to create a dataframe with all of the red_blue\nsplit points from the datajoint database\n\nApplications\n------------\n1. Query this dataframe for a high fidelity subset\n2. Plot single red-blue splits or for the entire segment\n'

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import connects_neuvue

# %% [markdown]
# # Step 1: Import API and configure API object with aws secret

# %%
from connects_neuvue.utils import aws_utils as aws
secret_dict = aws.get_secret()

# %%
from connects_neuvue.h01_c2 import api
fetcher = api.API(secret_dict=secret_dict)
fetcher
# Out:
# /usr/local/lib/python3.8/dist-packages/python_jsonschema_objects/__init__.py:113: UserWarning: Schema id not specified. Defaulting to 'self'
#   warnings.warn("Schema id not specified. Defaulting to 'self'")
# [2025-05-12 18:15:17,876][INFO]: Connecting admin@neurd-datajoint.cluster-cjc6cqmcqirl.us-east-1.rds.amazonaws.com:3306
# INFO - 2025-05-12 18:15:17,876 - connection - Connecting admin@neurd-datajoint.cluster-cjc6cqmcqirl.us-east-1.rds.amazonaws.com:3306
# [2025-05-12 18:15:18,421][INFO]: Connected admin@neurd-datajoint.cluster-cjc6cqmcqirl.us-east-1.rds.amazonaws.com:3306
# INFO - 2025-05-12 18:15:18,421 - connection - Connected admin@neurd-datajoint.cluster-cjc6cqmcqirl.us-east-1.rds.amazonaws.com:3306

# %% [markdown]
# # Application 1: Downloading all red blue splits

# %%
(red_blue_df,
 segment_error_df,
 error_df) = fetcher.red_blue_df(
        return_segment_error_df = True,
        return_error_df = True,
 )
# Out:
# 7281it [00:01, 6411.85it/s]

# %% [markdown]
# ## ** Warning **: features labeled "downstream_" were accidentally computed over all error branches on that limb and not subset of red/blue split (only valid if only 1 error of that type on that limb)

# %% [markdown]
# ## Dataframe with all individual red blue splits computed

# %%
red_blue_df
# Out:
#          segment_id  split_index                      error_type  cut_id  \
# 0         315456094            0         axon_on_dendrite_merges       0
# 1         315456094            0         axon_on_dendrite_merges       1
# 2         315456094            0           high_degree_branching       2
# 3         315456094            0            low_degree_branching       3
# 4         329194148            0         axon_on_dendrite_merges       0
# ...             ...          ...                             ...     ...
# 31855   98854509409            0  high_degree_branching_dendrite       0
# 31856  101028978632            0            low_degree_branching       0
# 31857  102275405869            0           high_degree_branching       0
# 31858  103526886623            0            double_back_dendrite       0
# 31859  103920063640            0         axon_on_dendrite_merges       0
#
#        filter_cut_id limb_name  limb_split_idx  skeletal_length  \
# 0                  0        L4               0        25511.516
# 1                  1        L6               0       461166.308
# 2                  0        L5               0        63134.082
# 3                  0        L5               0       158127.396
# 4                  0        L2               0         4897.572
# ...              ...       ...             ...              ...
# 31855              0        L0               0        75374.536
# 31856              0        L0               0        42229.447
# 31857              0        L0               0        46544.798
# 31858              0        L0               0        29622.405
# 31859              0        L1               0         5707.373
#
#        parent_branch_width                                       valid_points  \
# 0               552.661838  [[2787394.6666666665, 357874.93333333335, 1438...
# 1               361.700573  [[2778344.6666666665, 350692.3333333333, 6172....
# 2               190.988028  [[2799118.6666666665, 348181.86666666664, 4517...
# 3               525.824196  [[2794307.6666666665, 353550.7333333334, 31771...
# 4               152.734408  [[2617122.0, 373039.93333333335, 42096.9200000...
# ...                    ...                                                ...
# 31855           135.042608  [[3063178.6666666665, 682665.8333333334, 16972...
# 31856            29.177382  [[916169.7666666666, 1223039.3333333333, 16528...
# 31857            94.108346  [[3078483.6666666665, 1497608.0, 174188.833333...
# 31858           760.647022  [[3016864.3333333335, 1799908.0, 172960.633333...
# 31859          1535.718022  [[3031042.6666666665, 1877085.3333333333, 1746...
#
#        ... downstream_n_synapses_no_head_sum downstream_n_synapses_post_sum  \
# 0      ...                               0.0                            0.0
# 1      ...                               2.0                          214.0
# 2      ...                               0.0                            0.0
# 3      ...                               0.0                            2.0
# 4      ...                               0.0                            5.0
# ...    ...                               ...                            ...
# 31855  ...                               1.0                           42.0
# 31856  ...                               0.0                            4.0
# 31857  ...                               0.0                           15.0
# 31858  ...                               0.0                           29.0
# 31859  ...                               0.0                            0.0
#
#        downstream_n_synapses_pre_sum downstream_n_synapses_shaft_sum  \
# 0                                0.0                             0.0
# 1                                3.0                           211.0
# 2                                0.0                             0.0
# 3                                0.0                             0.0
# 4                               13.0                            17.0
# ...                              ...                             ...
# 31855                            0.0                            36.0
# 31856                            1.0                             0.0
# 31857                            0.0                             0.0
# 31858                            0.0                            29.0
# 31859                            0.0                             0.0
#
#       downstream_n_synapses_spine_sum downstream_skeletal_length_sum  \
# 0                                 0.0                   25511.515587
# 1                                 6.0                  461166.308434
# 2                                 0.0                   63134.082399
# 3                                 0.0                  158127.396023
# 4                                 1.0                  362034.131253
# ...                               ...                            ...
# 31855                             6.0                   75374.535719
# 31856                             0.0                   42229.447477
# 31857                             0.0                   46544.798365
# 31858                             0.0                   29622.404721
# 31859                             0.0                    5707.372822
#
#       downstream_total_spine_volume_sum  merge_coordinate_x_nm  \
# 0                          0.000000e+00           2.785004e+06
# 1                          1.795207e+08           2.778364e+06
# 2                          0.000000e+00           2.799008e+06
# 3                          0.000000e+00           2.797076e+06
# 4                          1.698964e+10           2.617073e+06
# ...                                 ...                    ...
# 31855                      6.149887e+08           3.063137e+06
# 31856                      0.000000e+00           9.169331e+05
# 31857                      0.000000e+00           3.079065e+06
# 31858                      0.000000e+00           3.016870e+06
# 31859                      0.000000e+00           3.030930e+06
#
#        merge_coordinate_y_nm  merge_coordinate_z_nm
# 0               3.586021e+05           12646.526867
# 1               3.505908e+05            6212.806111
# 2               3.461061e+05           40288.612439
# 3               3.519849e+05           34459.715978
# 4               3.728242e+05           42180.492663
# ...                      ...                    ...
# 31855           6.817234e+05          169467.836797
# 31856           1.225867e+06          166571.500000
# 31857           1.496084e+06          172320.318033
# 31858           1.801080e+06          172364.000000
# 31859           1.877151e+06          174630.390062
#
# [31860 rows x 67 columns]

# %% [markdown]
# ## Dataframe with the aggregated statistics of all error types for every segment

# %%
segment_error_df
# Out:
#          segment_id  split_index                      error_type  count  \
# 0         315456094            0         axon_on_dendrite_merges      2
# 1         315456094            0           high_degree_branching      1
# 2         315456094            0            low_degree_branching      1
# 3         329194148            0         axon_on_dendrite_merges     12
# 4         329194148            0          dendrite_internal_bend      1
# ...             ...          ...                             ...    ...
# 13038   98854509409            0  high_degree_branching_dendrite      1
# 13039  101028978632            0            low_degree_branching      1
# 13040  102275405869            0           high_degree_branching      1
# 13041  103526886623            0            double_back_dendrite      1
# 13042  103920063640            0         axon_on_dendrite_merges      1
#
#        downstream_skeletal_length_sum  downstream_n_synapses_sum  \
# 0                        4.866778e+05                      217.0
# 1                        6.313408e+04                        0.0
# 2                        1.581274e+05                        2.0
# 3                        3.485804e+06                      162.0
# 4                        5.848679e+04                        0.0
# ...                               ...                        ...
# 13038                    7.537454e+04                       42.0
# 13039                    4.222945e+04                        5.0
# 13040                    4.654480e+04                       15.0
# 13041                    2.962240e+04                       29.0
# 13042                    5.707373e+03                        0.0
#
#        downstream_n_synapses_post_sum  downstream_n_synapses_pre_sum  \
# 0                               214.0                            3.0
# 1                                 0.0                            0.0
# 2                                 2.0                            0.0
# 3                                45.0                          117.0
# 4                                 0.0                            0.0
# ...                               ...                            ...
# 13038                            42.0                            0.0
# 13039                             4.0                            1.0
# 13040                            15.0                            0.0
# 13041                            29.0                            0.0
# 13042                             0.0                            0.0
#
#        downstream_n_spines_sum
# 0                          5.0
# 1                          0.0
# 2                          0.0
# 3                        882.0
# 4                         14.0
# ...                        ...
# 13038                      7.0
# 13039                      0.0
# 13040                      0.0
# 13041                      0.0
# 13042                      0.0
#
# [13043 rows x 9 columns]

# %% [markdown]
# ## Dataframe with all aggregated stats for all error types across whole volume

# %%
error_df
# Out:
#                        error_type  count  downstream_skeletal_length_sum  \
# 0         axon_on_dendrite_merges  19964                    4.711809e+09
# 1          dendrite_internal_bend   1941                    3.029962e+08
# 2            double_back_dendrite   1943                    2.760095e+08
# 3           high_degree_branching   1381                    4.130196e+08
# 4  high_degree_branching_dendrite   5539                    2.983474e+09
# 5            low_degree_branching    966                    2.095960e+08
# 6              width_jump_up_axon     24                    4.392070e+06
# 7          width_jump_up_dendrite    102                    6.228800e+07
#
#    downstream_n_synapses_sum  downstream_n_synapses_post_sum  \
# 0                   429461.0                        272602.0
# 1                   224230.0                        219368.0
# 2                   202481.0                        197869.0
# 3                    25547.0                          8522.0
# 4                  2491391.0                       2435565.0
# 5                    15279.0                          6903.0
# 6                      444.0                           315.0
# 7                    61891.0                         59672.0
#
#    downstream_n_synapses_pre_sum  downstream_n_spines_sum
# 0                       156859.0                  66604.0
# 1                         4862.0                  86957.0
# 2                         4612.0                  94797.0
# 3                        17025.0                      0.0
# 4                        55826.0                1120322.0
# 5                         8376.0                      1.0
# 6                          129.0                      0.0
# 7                         2219.0                  27630.0

# %% [markdown]
# # Application 2: Plotting red blue splits

# %%
from connects_neuvue.utils import split_suggestion_utils as ssu

# %%
# check that the required plotting software is installed
ssu.check_ipvu()

# %%
segment_id = 1087542412
key = dict(segment_id=segment_id)
mesh = fetcher.fetch_segment_id_mesh(**key)

# %% [markdown]
# ## 2a: Plot individual red blue split

# %%
seg_red_blue_df = red_blue_df.query(f"segment_id == {segment_id}").reset_index(drop=True)
seg_red_blue_df
# Out:
#     segment_id  split_index                      error_type  cut_id  \
# 0   1087542412            0         axon_on_dendrite_merges       0
# 1   1087542412            0         axon_on_dendrite_merges       1
# 2   1087542412            0         axon_on_dendrite_merges       2
# 3   1087542412            0         axon_on_dendrite_merges       3
# 4   1087542412            0         axon_on_dendrite_merges       4
# 5   1087542412            0         axon_on_dendrite_merges       5
# 6   1087542412            0         axon_on_dendrite_merges       6
# 7   1087542412            0         axon_on_dendrite_merges       7
# 8   1087542412            0         axon_on_dendrite_merges       8
# 9   1087542412            0         axon_on_dendrite_merges       9
# 10  1087542412            0         axon_on_dendrite_merges      10
# 11  1087542412            0         axon_on_dendrite_merges      11
# 12  1087542412            0         axon_on_dendrite_merges      12
# 13  1087542412            0         axon_on_dendrite_merges      13
# 14  1087542412            0         axon_on_dendrite_merges      14
# 15  1087542412            0         axon_on_dendrite_merges      15
# 16  1087542412            0         axon_on_dendrite_merges      16
# 17  1087542412            0         axon_on_dendrite_merges      17
# 18  1087542412            0         axon_on_dendrite_merges      18
# 19  1087542412            0  high_degree_branching_dendrite      19
# 20  1087542412            0  high_degree_branching_dendrite      20
# 21  1087542412            0            double_back_dendrite      21
#
#     filter_cut_id limb_name  limb_split_idx  skeletal_length  \
# 0               0        L0               0        86707.677
# 1               1        L0               1        11014.610
# 2               2        L0               2         4936.446
# 3               3        L0               3         4581.813
# 4               4        L0               4        79399.333
# 5               5        L0               5         4751.129
# 6               6        L0               6         4759.760
# 7               7        L0               7         4286.511
# 8               8        L0               8         4942.517
# 9               9        L0               9         6290.407
# 10             10        L1               0         9587.010
# 11             11        L1               1        15536.675
# 12             12        L1               2        62549.583
# 13             13        L2               0        18576.055
# 14             14        L2               1         4142.598
# 15             15        L2               2         4399.930
# 16             16        L2               3         7499.680
# 17             17        L2               4         4498.071
# 18             18        L3               0         7040.473
# 19              0        L2               0       161871.118
# 20              1        L2               1        72121.285
# 21              0        L0               0        82383.410
#
#     parent_branch_width                                       valid_points  \
# 0           1052.487777  [[2901898.6666666665, 718319.9, 41008.11], [29...
# 1            799.693246  [[2939485.0, 717861.0, 30576.39333333333], [29...
# 2            854.086938  [[2946170.6666666665, 711271.2000000001, 30738...
# 3            463.345073  [[2845429.6666666665, 750819.5666666668, 33534...
# 4            547.838941  [[2981452.0, 719311.2666666666, 8884.605333333...
# 5           1343.511592  [[2850813.3333333335, 749925.2333333334, 33335...
# 6           1241.805947  [[2876181.0, 722929.2666666667, 40168.98333333...
# 7            599.534052  [[3092095.0, 685317.7000000001, 36206.49], [30...
# 8           1415.047896  [[2881162.6666666665, 719248.1333333333, 41817...
# 9            788.517455  [[2896154.6666666665, 672917.3333333334, 43900...
# 10           503.399427  [[2885067.3333333335, 917351.8666666667, 41998...
# 11           573.583220  [[2794815.0, 948501.7000000001, 23045.21333333...
# 12           587.608460  [[2842953.3333333335, 856229.1, 17402.55333333...
# 13           649.697483  [[2730264.0, 785300.0, 22503.33666666667], [27...
# 14           702.648653  [[2732819.6666666665, 824847.3666666666, 11383...
# 15           556.147472  [[2740773.0, 727827.1666666666, 50871.88000000...
# 16           503.460026  [[2753352.0, 770381.3333333334, 2112.031666666...
# 17           582.323722  [[2755564.0, 812458.2666666666, 50052.50333333...
# 18           482.916907  [[2828517.3333333335, 816793.6666666666, 16451...
# 19           848.999805  [[2672183.0, 719822.7999999999, 35862.21666666...
# 20           388.851368  [[2675062.0, 720858.6666666666, 35400.52333333...
# 21          1047.374310  [[2921479.0, 728000.5666666668, 35418.63], [29...
#
#     ... downstream_n_synapses_no_head_sum downstream_n_synapses_post_sum  \
# 0   ...                               0.0                           10.0
# 1   ...                               0.0                           10.0
# 2   ...                               0.0                           10.0
# 3   ...                               0.0                           10.0
# 4   ...                               0.0                           10.0
# 5   ...                               0.0                           10.0
# 6   ...                               0.0                           10.0
# 7   ...                               0.0                           10.0
# 8   ...                               0.0                           10.0
# 9   ...                               0.0                           10.0
# 10  ...                               0.0                            3.0
# 11  ...                               0.0                            3.0
# 12  ...                               0.0                            3.0
# 13  ...                               0.0                            3.0
# 14  ...                               0.0                            3.0
# 15  ...                               0.0                            3.0
# 16  ...                               0.0                            3.0
# 17  ...                               0.0                            3.0
# 18  ...                               0.0                            1.0
# 19  ...                              63.0                          308.0
# 20  ...                              63.0                          308.0
# 21  ...                              14.0                           80.0
#
#     downstream_n_synapses_pre_sum downstream_n_synapses_shaft_sum  \
# 0                            11.0                            21.0
# 1                            11.0                            21.0
# 2                            11.0                            21.0
# 3                            11.0                            21.0
# 4                            11.0                            21.0
# 5                            11.0                            21.0
# 6                            11.0                            21.0
# 7                            11.0                            21.0
# 8                            11.0                            21.0
# 9                            11.0                            21.0
# 10                            9.0                            12.0
# 11                            9.0                            12.0
# 12                            9.0                            12.0
# 13                            0.0                             3.0
# 14                            0.0                             3.0
# 15                            0.0                             3.0
# 16                            0.0                             3.0
# 17                            0.0                             3.0
# 18                            0.0                             1.0
# 19                            2.0                           149.0
# 20                            2.0                           149.0
# 21                            0.0                            42.0
#
#    downstream_n_synapses_spine_sum downstream_skeletal_length_sum  \
# 0                              0.0                  211670.204962
# 1                              0.0                  211670.204962
# 2                              0.0                  211670.204962
# 3                              0.0                  211670.204962
# 4                              0.0                  211670.204962
# 5                              0.0                  211670.204962
# 6                              0.0                  211670.204962
# 7                              0.0                  211670.204962
# 8                              0.0                  211670.204962
# 9                              0.0                  211670.204962
# 10                             0.0                   87673.267858
# 11                             0.0                   87673.267858
# 12                             0.0                   87673.267858
# 13                             0.0                   39116.335094
# 14                             0.0                   39116.335094
# 15                             0.0                   39116.335094
# 16                             0.0                   39116.335094
# 17                             0.0                   39116.335094
# 18                             0.0                    7040.472960
# 19                           161.0                  233992.403191
# 20                           161.0                  233992.403191
# 21                            38.0                   82383.409553
#
#    downstream_total_spine_volume_sum  merge_coordinate_x_nm  \
# 0                       0.000000e+00           2.903460e+06
# 1                       0.000000e+00           2.940390e+06
# 2                       0.000000e+00           2.946980e+06
# 3                       0.000000e+00           2.846930e+06
# 4                       0.000000e+00           2.981826e+06
# 5                       0.000000e+00           2.850840e+06
# 6                       0.000000e+00           2.875925e+06
# 7                       0.000000e+00           3.093003e+06
# 8                       0.000000e+00           2.880850e+06
# 9                       0.000000e+00           2.896507e+06
# 10                      0.000000e+00           2.884765e+06
# 11                      0.000000e+00           2.794801e+06
# 12                      0.000000e+00           2.843879e+06
# 13                      0.000000e+00           2.729480e+06
# 14                      0.000000e+00           2.733060e+06
# 15                      0.000000e+00           2.739904e+06
# 16                      0.000000e+00           2.752691e+06
# 17                      0.000000e+00           2.755520e+06
# 18                      0.000000e+00           2.827810e+06
# 19                      1.983658e+10           2.671999e+06
# 20                      1.983658e+10           2.674074e+06
# 21                      3.903323e+09           2.922760e+06
#
#     merge_coordinate_y_nm  merge_coordinate_z_nm
# 0           718942.000000           40737.000000
# 1           717523.000000           30742.500000
# 2           710075.000000           30785.900000
# 3           751748.000000           33099.200000
# 4           718410.800680            9291.441137
# 5           749190.000000           33685.900000
# 6           721483.000000           40355.150000
# 7           685324.881257           36259.830792
# 8           717723.000000           41848.200000
# 9           672020.255556           43803.563333
# 10          917236.429557           43020.836471
# 11          949515.777130           23067.528968
# 12          856668.715022           17850.197024
# 13          784931.000000           22834.800000
# 14          825705.000000           10539.200000
# 15          727606.124707           51394.708332
# 16          769837.033631            1721.540408
# 17          813035.000000           50364.400000
# 18          816539.625329          164757.622994
# 19          719667.625747           36037.694324
# 20          720794.743233           35470.708239
# 21          727937.000000           35427.200000
#
# [22 rows x 67 columns]

# %%
idx = 11
red_blue_dict = seg_red_blue_df.iloc[idx,:].to_dict()

ssu.plot_red_blue_split_dict(
    split_dict = red_blue_dict,
    mesh = mesh
)
# Out:
# Segment_id 1087542412 split_index 0:
# axon_on_dendrite_merges split #11 (on limb L1)
#   skeletal_length = 15536.67
# HBox(children=(FloatSlider(value=0.25, description='Size', max=3.0), Dropdown(description='Geo', index=3, opti…
# HBox(children=(FloatSlider(value=0.25, description='Size', max=3.0), Dropdown(description='Geo', index=3, opti…
# HBox(children=(FloatSlider(value=0.25, description='Size', max=3.0), Dropdown(description='Geo', index=3, opti…
# Container(figure=Figure(box_center=[0.5, 0.5, 0.5], box_size=[1.0, 1.0, 1.0], camera=PerspectiveCamera(fov=45.…

# %% [markdown]
# ## Plot all red_blue splits for a neuron

# %%
ssu.plot_red_blue_for_segment(
    segment_id,
    red_blue_df=red_blue_df,
    mesh=mesh,
)
# Out:
# For 1087542412_0: # of total splits = 22
#   axon_on_dendrite_merges: 19 (red)
#   double_back_dendrite: 1 (pink)
#   high_degree_branching_dendrite: 2 (orange)
# /usr/local/lib/python3.8/dist-packages/traittypes/traittypes.py:97: UserWarning: Given trait value dtype "float64" does not match required type "float64". A coerced copy has been created.
#   warnings.warn(
# HBox(children=(FloatSlider(value=0.15, description='Size', max=3.0), Dropdown(description='Geo', index=3, opti…
# HBox(children=(FloatSlider(value=0.15, description='Size', max=3.0), Dropdown(description='Geo', index=3, opti…
# HBox(children=(FloatSlider(value=0.15, description='Size', max=3.0), Dropdown(description='Geo', index=3, opti…
# HBox(children=(FloatSlider(value=0.15, description='Size', max=3.0), Dropdown(description='Geo', index=3, opti…
# HBox(children=(FloatSlider(value=0.15, description='Size', max=3.0), Dropdown(description='Geo', index=3, opti…
# HBox(children=(FloatSlider(value=0.15, description='Size', max=3.0), Dropdown(description='Geo', index=3, opti…
# Container(figure=Figure(box_center=[0.5, 0.5, 0.5], box_size=[1.0, 1.0, 1.0], camera=PerspectiveCamera(fov=45.…
